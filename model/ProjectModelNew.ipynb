# %% [markdown]
# # PROJECT OVERVIEW
# ## Institute of Computer Studies Graduate Tracer Study (2022-2023)
#
#
# Problem Description:
#
#     Predict the Employability of the CCS Students based on given attributes
#         - Technical Support Specialist
#         - Software Engineer / Programmer
#         - Others / Non-IT/CS Related job
#         - Administrative Assistant
#         - Academician
#
#
# ### Description of columns
#
# CCS Graduates from 2016-2022 using google form
#
#     Graduates Basic Information
#         - First Name
#         - Last Name
#         - Cellphone Number
#         - Sex
#         - Email Address
#
#     Graduates academic information
#         - Degree Completed
#         - Year Graduated
#         - Shiftee
#
#     Employment information
#         - Have_you_ever_been_employed_after_graduation
#         - Industry
#         - Industry (Others)
#         - Designation_Position
#         - Designation_Position_Others
#         - Type_of_ Employment
#         - Place of Work / Employer
#         - Employment_Status
#         - Company_Name
#         - When was your first employment (month and year)?
#         - Is_it_related_to_the_degree_you_completed?
#         - How long have you been working in your first employment?  (Years or Months)
#         - Awards received in your first work
#         - Are you still employed with your first job?
#         - Industry_1
#         - Industry_Others_1
#         - Designation / Position
#         - Designation_Position_Others_1
#         - Type of Employment
#         - Place of Work / Employer.1
#         - Employment Status
#         - Company Name
#         - When was your first day of employment of your current work (month and year)?
#         - Is it related to the degree you completed?',
#         - How long have you been working in this current employment? (Year, Month)
#         - Awards received in your current work
#         - Did WMSU or the Department of Computer Science/Information Technology help you in your current job?
#         - Was_the_curriculum_you_had_in_college_relevant_to_your_job?
#         - Comments or Suggestions on the BSCS and/or BSIT curriculum.
#
#     Courses available
#         0- Stands for false
#         1- Stands for true
#
#         ComProg 1 Enrolled
#         ComProg 1 INC
#         ComProg 1 DRP
#         ComProg 1 (1st try)
#         ComProg 1 (2nd try)
#         ComProg 2 Enrolled
#         ComProg 2 INC	ComProg 2 DRP
#         ComProg 2 (1st try)
#         ComProg 2 (2nd try)
#         Intro to Computing Enrolled
#         Intro to Computing INC
#         Intro to Computing DRP
#         Intro to Computing  (1st try)
#         Intro to Computing (2nd try)
#         Database 1 Enrolled
#         Database 1 INC
#         Database 1 DRP
#         Database 1 (1st try)
#         Database 1 (2nd try)
#         Database Enrolled
#         Database 2 INC
#         Database DRP
#         Database 2 (1st try)
#         Database 2
#         Database Management System Enrolled
#         Database Management System INC
#         Database Management System DRP
#         Database Management System (1st try)
#         DATABASE MANAGEMENT SYSTEMS (2nd try)
#         Advance Database Enrolled
#         Advance Database INC
#         Advance Database DRP
#         Advance Database (1st try)
#         Advance Database (2nd try)
#         Info Management Enrolled
#         Info Management INC
#         Info Management DRP
#         Info Management  (1st try)
#         Info Management (2nd try)
#         WebProg Enrolled
#         WebProg INC
#         WebProg DRP
#         WebProg  (1st try)
#         WebProg (2nd try)
#         Networking 1 Enrolled
#         Networking 1 INC
#         Networking 1 DRP
#         Networking 1 (1st try)
#         Networking 1 (2nd try)
#         Networking 2 Enrolled
#         Networking 2 INC
#         Networking 2 DRP
#         Network 2 (1st try)
#         Networking 2 (2nd try)
#         Network Management Enrolled
#         Network Management INC
#         Network Management  DRP
#         Network Management  (1st try)
#         Network Management (2nd try)
#         Software Engineering Enrolled
#         Software Engineering INC
#         Software Engineering DRP
#         Software Engineering (1st try)
#         Software Engineering (2nd try)
#         Software Engineering 1 Enrolled
#         Software Engineering 1 (INC)
#         Software Engineering 1 DRP
#         Software Engineering 1 (1st try)
#         Software Engineering 1 (2nd try)
#         Software Engineering 2 Enrolled
#         Software Engineering 2 INC
#         Software Engineering 2 DRP
#         Software Engineering 2 (1st try)
#         Software Engineering 2 (2nd try)
#         Operating System Enrolled
#         Operating System INC
#         Operating System DRP
#         Operating System (1st try)
#         Operating System (2nd try)
#         Elective 1 Enrolled
#         Elective 1 INC
#         Elective 1 DRP
#         Elective 1 (1st try)
#         Elective 1 (2nd try)
#         Elective 2 Enrolled
#         Elective 2 DRP
#         Elective 2 INC
#         Elective 2 UW
#         Elective 2 (1st try)
#         Elective 2 (2nd try)
#         Elective 3 Enrolled
#         Elective 3 INC
#         Elective 3 DRP
#         Elective 3 (1st try)
#         Elective 3 (2nd try)
#         Data Structures Enrolled
#         Data Structures INC
#         Data Structures DRP
#         Data Structures (1st try)
#         Data Structures (2nd try)
#         Digital Design Enrolled
#         Digital Design INC
#         Digital Design DRP
#         Digital Design (1st try)
#         Digital Design (2nd try)
#         Architecture and Organization Enrolled
#         Architecture and Organization INC
#         Architecture and Organization DRP
#         Architecture and Organization (1st try)
#         Architecture and Organization (2nd try)
#         Programming Languages Enrolled
#         Programming Languages DRP
#         Programming Languages INC
#         Programming Languages (1st try)
#         Programming Languages (2nd try)
#         Modelling and Simulation Enrolled
#         Modelling and Simulation INC
#         Modelling and Simulation DRP
#         Modelling and Simulation (1st try)
#         Modelling and Simulation (2nd try)
#         Application Dev and Emerging Tech Enrolled
#         Application Dev and Emerging Tech INC
#         Application Dev and Emerging Tech DRP
#         Application Dev and Emerging Tech (1st try)
#         Application Dev and Emerging Tech (2nd try)
#         System Analysis and Design Enrolled
#         System Analysis and Design INC
#         System Analysis and Design DRP
#         System Analysis and Design (1st try)
#         System Analysis and Design (2nd try)
#         Distributed Systems Enrolled
#         Distributed Systems INC
#         Distributed Systems DRP
#         Distributed Systems (1st try)
#         Distributed Systems
#         Integrative Programming and Tech Enrolled
#         Integrative Programming and Tech INC
#         Integrative Programming and Tech DRP
#         Integrative Programming and Tech (1st try)
#         Integrative Programming and Tech (2nd try)
#         System Integration and Architecture Enrolled
#         System Integration and Architecture INC
#         System Integration and Architecture DRP
#         System Integration and Architecture (1st try)
#         System Integration and Architecture (2nd try)
#         Information Assurance and Security 1 Enrolled
#         Information Assurance and Security 1 INC
#         Information Assurance and Security 1 DRP
#         Information Assurance and Security 1 (1st try)
#         Information Assurance and Security 1 (2nd try)
#         Information Assurance and Security 2 Enrolled
#         Information Assurance and Security 2 (INC)
#         Information Assurance and Security 2 DRP
#         Information Assurance and Security 2 (1st try)
#         Information Assurance and Security 2 (2nd try)
#         Information Assurance and Security Enrolled
#         Information Assurance and Security INC
#         Information Assurance and Security DRP
#         Information Assurance and Security 1st try
#         Information Assurance and Security (2nd try)
#         Human and Computer Integration Enrolled
#         Human and Computer Integration INC
#         Human and Computer Integration DRP
#         Human and Computer Integration (1st try)
#         Human and Computer Integration (2nd try)
#         Practicum/Industry Immersion Enrolled
#         Practicum/Industry Immersion (INC)
#         Practicum/Industry Immersion DRP
#         Practicum/Industry Immersion (1st try)
#         Practicum/Industry Immersion (2nd try
#
#
#
# # Objectives
# #### General Objective:
# - The main goal of this study is to build a prediction model using Machine Learning Techniques that can predict if a CCS student will land IT/CS Related Job after they'll graduate.
#
# #### Specific Objective:
# - The specific objective

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from pandas import DataFrame
from sklearn.metrics import accuracy_score, roc_auc_score

sns.set_style("whitegrid")
plt.style.use("fivethirtyeight")

# %%
dataset = pd.read_csv("Institute-of-Computer-Studies-Graduate-Tracer-Study-2021-2022-Responses(ALTERED).csv")

# %%
dataset.head()
# Out:
#          Timestamp  First_Name Last_Name  \
# 0  6/18/2022 10:41      Joshua    Fabian
# 1  6/18/2022 10:42      Adrian  Agcaoili
# 2  6/18/2022 10:42  Nur-Radia     Lagoyo
# 3  6/18/2022 10:45    Marjorie   Velario
# 4  6/18/2022 10:54    Rhamirl     Jaafar
#
#                                     Degree_Completed  Year_Graduated:  \
# 0            Bachelor of Science in Computer Science             2021
# 1      Bachelor of Science in Information Technology             2021
# 2      Bachelor of Science in Information Technology             2021
# 3  Bachelor of Science in Computer Science Major ...             2020
# 4      Bachelor of Science in Information Technology             2020
#
#   Curriculum  Units Cellphone_Number                     Email_Address  \
# 0  2016-2017   82.0       9276329584        joshuafabian0105@gmail.com
# 1  2016-2017  111.0       9605075322        adrianagcaoili20@gmail.com
# 2  2016-2017  111.0       9550013442            lagoyodeea5@gmail.com
# ...

# %% [markdown]
# # EDA

# %%
dataset.shape
# Out:
# (103, 212)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Columns: 212 entries, Timestamp to Suggested_job_role
# dtypes: float64(55), int64(120), object(37)
# memory usage: 170.7+ KB

# %%
dataset.isna().sum()
# Out:
# Timestamp                                 0
# First_Name                                0
# Last_Name                                 0
# Degree_Completed                          0
# Year_Graduated:                           0
#                                          ..
# Practicum/Industry Immersion (INC)        0
# Practicum/Industry Immersion DRP          0
# Practicum/Industry Immersion (1st try)    0
# Practicum/Industry Immersion (2nd try)    0
# Suggested_job_role                        0
# Length: 212, dtype: int64

# %%
dataset.describe()
# Out:
#        Year_Graduated:       Units  \
# count       103.000000   98.000000
# mean       2019.038835   84.816327
# std           1.748514   18.352981
# min        2016.000000   65.000000
# 25%        2018.000000   76.000000
# 50%        2018.000000   76.000000
# 75%        2020.000000  110.000000
# max        2022.000000  118.000000
#
#        Did WMSU or the Department of Computer Science/Information Technology help you in your current job?  \
# count                                         101.000000
# mean                                            3.920792
# std                                             1.230310
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             5.000000
#
#          SHIFTEE   ComProg 1 Enrolled  ComProg  1 INC  ComProg 1 DRP  \
# ...

# %% [markdown]
# ## Variable Identification

# %%
colList = list(dataset.columns)
colList
# Out:
# ['Timestamp',
#  'First_Name',
#  'Last_Name',
#  'Degree_Completed',
#  'Year_Graduated:',
#  'Curriculum',
#  'Units',
#  'Cellphone_Number',
#  'Email_Address',
#  'Sex',
#  'Have_you_ever_been_employed_after_graduation?',
#  'Industry',
#  'Industry (Others)',
#  'Designation_Position',
#  'Designation_Position_Others',
#  'Type_of_ Employment',
#  'Place of Work / Employer',
#  'Employment_Status',
#  'Company_Name',
#  'When was your first employment (month and year)?',
#  'Is_it_related_to_the_degree_you_completed?',
#  'How long have you been working in your first employment?  (Years or Months)',
#  'Awards received in your first work',
#  'Are you still employed with your first job?',
#  'Industry_1',
#  'Industry_Others_1',
#  'Designation / Position',
#  'Designation_Position_Others_1',
#  'Type of Employment',
#  'Place of Work / Employer.1',
#  'Employment Status',
#  'Company Name',
#  'When was your first day of employment of your current work (month and year)?',
# ...

# %%
DETECT_USEFUL_FEATURES = [
 'Shiftee',
 'ComProg_1_1st',
 'ComProg_1_2nd',
 'ComProg_2_1st',
 'ComProg_2_2nd',
 'Intro_to_Computing_1st',
 'Intro_to_Computing_2nd',
 'Database_1_1st',
 'Database 1 (2nd try)',
 'Database_2_1st',
 'Database 2',
 'Database_Management_System_1st',
 'DATABASE MANAGEMENT SYSTEMS (2nd try)',
 'Advance_Database_1st',
 'Advance_Database_2nd',
 'Info_Management_1st',
 'Info_Management_2nd',
 'WebProg_1st',
 'WebProg_2nd',
 'Networking_1_1st',
 'Networking_1_2nd',
 'Networking_2_1st',
 'Networking_2_2nd',
 'Network_Management_1st',
 'Network_Management_2nd',
 'Software_Engineering_1st',
 'Software_Engineering_2nd',
 'Software_Engineering_1_1st',
 'Software_Engineering_1_2nd',
 'Software_Engineering_2_1st',
 'Software_Engineering_2_2nd',
 'Operating_System_1st',
 'Operating_System_2nd',
 'Elective_1_1st',
 'Elective_1_2nd',
 'Elective_2_1st',
 'Elective_2_2nd',
 'Elective_3_1st',
 'Elective_3_2nd',
 'Data_Structures_1st',
 'Data_Structures_2nd',
 'Digital_Design_1st',
 'Digital_Design_2nd',
 'Architecture_and_Organization_1st',
 'Architecture_and_Organization_2nd',
 'Programming_Languages_1st',
 'Programming_Languages_2nd',
 'Modelling_and_Simulation_1st',
 'Modelling_and_Simulation_2nd',
 'Application_Dev_and_Emerging_Tech_1st',
 'Application_Dev_and_Emerging_Tech_2nd',
 'System_Analysis_and_Design_1st',
 'System_Analysis_and_Design_2nd',
 'Distributed Systems (1st try)',
 'Distributed Systems',
 'Integrative_Programming_and_Tech_1st',
 'Integrative_Programming_and_Tech_2nd',
 'System_Integration_and_Architecture_1st',
 'System_Integration_and_Architecture_2nd',
 'Information_Assurance_and_Security_1_1st',
 'Information_Assurance_and_Security_1_2nd',
 'Information_Assurance_and_Security_2_1st',
 'Information_Assurance_and_Security_2_2nd',
 'Information_Assurance_and_Security_1st',
 'Information_Assurance_and_Security_2nd',
 'Human_and_Computer_Integration_1st',
 'Human_and_Computer_Integration_2nd',
 'Practicum_Industry_Immersion_1st',
 'Practicum_Industry_Immersion_2nd'
]

# %%
FEATURE_ENGINEERED = [
    'Sex',
    'Degree_Completed',
    'Curriculum',
    'Units',
    'Shiftee',
]

# %% [markdown]
# ### Predictor (Input)

# %%
IT_FEATURES = [
     'Sex',
     'Shiftee',
     'ComProg_1_1st',
     'ComProg_1_2nd',
     'ComProg_2_1st',
     'ComProg_2_2nd',
     'Intro_to_Computing_1st',
     'Intro_to_Computing_2nd',
     'Info_Management_1st',
     'Info_Management_2nd',
     'Operating_System_1st',
     'Operating_System_2nd',
     'Elective_1_1st',
     'Elective_1_2nd',
     'Elective_2_1st',
     'Elective_2_2nd',
     'Elective_3_1st',
     'Elective_3_2nd',
     'Data_Structures_1st',
     'Data_Structures_2nd',
     'Application_Dev_and_Emerging_Tech_1st',
     'Application_Dev_and_Emerging_Tech_2nd',
     'Human_and_Computer_Integration_1st',
     'Human_and_Computer_Integration_2nd',
     'Practicum_Industry_Immersion_1st',
     'Practicum_Industry_Immersion_2nd',
     'Integrative_Programming_and_Tech_1st',
     'Integrative_Programming_and_Tech_2nd',
     'System_Integration_and_Architecture_1st',
     'System_Integration_and_Architecture_2nd',
     'Information_Assurance_and_Security_1_1st',
     'Information_Assurance_and_Security_1_2nd',
     'Information_Assurance_and_Security_2_1st',
     'Information_Assurance_and_Security_2_2nd',
     'Software_Engineering_1st',
     'Software_Engineering_2nd',
     'Networking_1_1st',
     'Networking_1_2nd',
     'Networking_2_1st',
     'Networking_2_2nd',
     'WebProg_1st',
     'WebProg_2nd'
]

IT_REFERENCE = [
     'Sex',
     'Shiftee',
     'ComProg_1_1st',
     'ComProg_1_2nd',
     'ComProg_2_1st',
     'ComProg_2_2nd',
     'Intro_to_Computing_1st',
     'Intro_to_Computing_2nd',
     'Info_Management_1st',
     'Info_Management_2nd',
     'Operating_System_1st',
     'Operating_System_2nd',
     'Elective_1_1st',
     'Elective_1_2nd',
     'Elective_2_1st',
     'Elective_2_2nd',
     'Elective_3_1st',
     'Elective_3_2nd',
     'Data_Structures_1st',
     'Data_Structures_2nd',
     'Application_Dev_and_Emerging_Tech_1st',
     'Application_Dev_and_Emerging_Tech_2nd',
     'Human_and_Computer_Integration_1st',
     'Human_and_Computer_Integration_2nd',
     'Practicum_Industry_Immersion_1st',
     'Practicum_Industry_Immersion_2nd',
     'Integrative_Programming_and_Tech_1st',
     'Integrative_Programming_and_Tech_2nd',
     'System_Integration_and_Architecture_1st',
     'System_Integration_and_Architecture_2nd',
     'Information_Assurance_and_Security_1_1st',
     'Information_Assurance_and_Security_1_2nd',
     'Information_Assurance_and_Security_2_1st',
     'Information_Assurance_and_Security_2_2nd',
     'Software_Engineering_1st',
     'Software_Engineering_2nd',
     'Networking_1_1st',
     'Networking_1_2nd',
     'Networking_2_1st',
     'Networking_2_2nd',
     'WebProg_1st',
     'WebProg_2nd',
     'Suggested_job_role'
]

# %%
CS_FEATURES = [
     'Sex',
     'Shiftee',
     'ComProg_1_1st',
     'ComProg_1_2nd',
     'ComProg_2_1st',
     'ComProg_2_2nd',
     'Intro_to_Computing_1st',
     'Intro_to_Computing_2nd',
     'Info_Management_1st',
     'Info_Management_2nd',
     'Operating_System_1st',
     'Operating_System_2nd',
     'Elective_1_1st',
     'Elective_1_2nd',
     'Elective_2_1st',
     'Elective_2_2nd',
     'Elective_3_1st',
     'Elective_3_2nd',
     'Data_Structures_1st',
     'Data_Structures_2nd',
     'Application_Dev_and_Emerging_Tech_1st',
     'Application_Dev_and_Emerging_Tech_2nd',
     'Human_and_Computer_Integration_1st',
     'Human_and_Computer_Integration_2nd',
     'Practicum_Industry_Immersion_1st',
     'Practicum_Industry_Immersion_2nd',
     'Digital_Design_1st',
     'Digital_Design_2nd',
     'Architecture_and_Organization_1st',
     'Architecture_and_Organization_2nd',
     'Programming_Languages_1st',
     'Programming_Languages_2nd',
     'Modelling_and_Simulation_1st',
     'Modelling_and_Simulation_2nd',
     'Information_Assurance_and_Security_1st',
     'Information_Assurance_and_Security_1_2nd',
     'Software_Engineering_1_1st',
     'Software_Engineering_1_2nd',
     'Software_Engineering_2_1st',
     'Software_Engineering_2_2nd',
     'Network_Management_1st',
     'Network_Management_2nd',
     'Advance_Database_1st',
     'Advance_Database_2nd',
     'WebProg_1st',
     'WebProg_2nd'
]

CS_REFERENCE = [
     'Sex',
     'Shiftee',
     'ComProg_1_1st',
     'ComProg_1_2nd',
     'ComProg_2_1st',
     'ComProg_2_2nd',
     'Intro_to_Computing_1st',
     'Intro_to_Computing_2nd',
     'Info_Management_1st',
     'Info_Management_2nd',
     'Operating_System_1st',
     'Operating_System_2nd',
     'Elective_1_1st',
     'Elective_1_2nd',
     'Elective_2_1st',
     'Elective_2_2nd',
     'Elective_3_1st',
     'Elective_3_2nd',
     'Data_Structures_1st',
     'Data_Structures_2nd',
     'Application_Dev_and_Emerging_Tech_1st',
     'Application_Dev_and_Emerging_Tech_2nd',
     'Human_and_Computer_Integration_1st',
     'Human_and_Computer_Integration_2nd',
     'Practicum_Industry_Immersion_1st',
     'Practicum_Industry_Immersion_2nd',
     'Digital_Design_1st',
     'Digital_Design_2nd',
     'Architecture_and_Organization_1st',
     'Architecture_and_Organization_2nd',
     'Programming_Languages_1st',
     'Programming_Languages_2nd',
     'Modelling_and_Simulation_1st',
     'Modelling_and_Simulation_2nd',
     'Information_Assurance_and_Security_1st',
     'Information_Assurance_and_Security_1_2nd',
     'Software_Engineering_1_1st',
     'Software_Engineering_1_2nd',
     'Software_Engineering_2_1st',
     'Software_Engineering_2_2nd',
     'Network_Management_1st',
     'Network_Management_2nd',
     'Advance_Database_1st',
     'Advance_Database_2nd',
     'WebProg_1st',
     'WebProg_2nd',
     'Suggested_job_role'
]

# %% [markdown]
# ### Target (Output)

# %%
TARGET = 'Suggested_job_role'

# %%
X_USE = dataset[DETECT_USEFUL_FEATURES]

# %%
X_IT = dataset[IT_FEATURES]
X_CS = dataset[CS_FEATURES]

# %%
CS_REF = dataset[CS_REFERENCE]
IT_REF = dataset[IT_REFERENCE]

# %%
Y = dataset[TARGET]

# %%
Cat_Y = dataset[TARGET]

# %%
X_IT = X_IT.replace(np.nan, 0)
X_CS = X_CS.replace(np.nan, 0)
X_USE = X_USE.replace(np.nan, 0)

# %%
# Target
Y.value_counts()
# Out:
# Technical Support Specialist      34
# Software Engineer / Programmer    31
# Administrative Assistant          25
# Academician                       13
# Name: Suggested_job_role, dtype: int64

# %%
# X = dataset[FEATURES]
# X_pca = dataset[FEATURES]

# %%
#FILL NAN VALUE TO 0
# X = X.replace(np.nan, 0)
# X_pca = X_pca.replace(np.nan, 0)

# %%
# Predictor for IT
colListX = list(X_IT.columns)
colListX
# Out:
# ['Sex',
#  'Shiftee',
#  'ComProg_1_1st',
#  'ComProg_1_2nd',
#  'ComProg_2_1st',
#  'ComProg_2_2nd',
#  'Intro_to_Computing_1st',
#  'Intro_to_Computing_2nd',
#  'Info_Management_1st',
#  'Info_Management_2nd',
#  'Operating_System_1st',
#  'Operating_System_2nd',
#  'Elective_1_1st',
#  'Elective_1_2nd',
#  'Elective_2_1st',
#  'Elective_2_2nd',
#  'Elective_3_1st',
#  'Elective_3_2nd',
#  'Data_Structures_1st',
#  'Data_Structures_2nd',
#  'Application_Dev_and_Emerging_Tech_1st',
#  'Application_Dev_and_Emerging_Tech_2nd',
#  'Human_and_Computer_Integration_1st',
#  'Human_and_Computer_Integration_2nd',
#  'Practicum_Industry_Immersion_1st',
#  'Practicum_Industry_Immersion_2nd',
#  'Integrative_Programming_and_Tech_1st',
#  'Integrative_Programming_and_Tech_2nd',
#  'System_Integration_and_Architecture_1st',
#  'System_Integration_and_Architecture_2nd',
#  'Information_Assurance_and_Security_1_1st',
#  'Information_Assurance_and_Security_1_2nd',
# ...

# %%
# Predictor for CS
colListX = list(X_CS.columns)
colListX
# Out:
# ['Sex',
#  'Shiftee',
#  'ComProg_1_1st',
#  'ComProg_1_2nd',
#  'ComProg_2_1st',
#  'ComProg_2_2nd',
#  'Intro_to_Computing_1st',
#  'Intro_to_Computing_2nd',
#  'Info_Management_1st',
#  'Info_Management_2nd',
#  'Operating_System_1st',
#  'Operating_System_2nd',
#  'Elective_1_1st',
#  'Elective_1_2nd',
#  'Elective_2_1st',
#  'Elective_2_2nd',
#  'Elective_3_1st',
#  'Elective_3_2nd',
#  'Data_Structures_1st',
#  'Data_Structures_2nd',
#  'Application_Dev_and_Emerging_Tech_1st',
#  'Application_Dev_and_Emerging_Tech_2nd',
#  'Human_and_Computer_Integration_1st',
#  'Human_and_Computer_Integration_2nd',
#  'Practicum_Industry_Immersion_1st',
#  'Practicum_Industry_Immersion_2nd',
#  'Digital_Design_1st',
#  'Digital_Design_2nd',
#  'Architecture_and_Organization_1st',
#  'Architecture_and_Organization_2nd',
#  'Programming_Languages_1st',
#  'Programming_Languages_2nd',
#  'Modelling_and_Simulation_1st',
#  'Modelling_and_Simulation_2nd',
# ...

# %%
X_CS
# Out:
#         Sex  Shiftee  ComProg_1_1st  ComProg_1_2nd  ComProg_2_1st  \
# 0      Male      1.0           2.00              0           2.75
# 1      Male      0.0           1.75              0           2.00
# 2    Female      1.0           1.50              0           1.50
# 3    Female      0.0           2.50              0           3.00
# 4      Male      1.0           1.75              0           1.25
# ..      ...      ...            ...            ...            ...
# 98   Female      0.0           2.00              0           2.25
# 99   Female      0.0           1.75              0           2.00
# 100    Male      1.0           1.75              0           1.75
# 101  Female      1.0           2.75              0           3.00
# 102  Female      0.0           1.50              0           1.50
#
#      ComProg_2_2nd  Intro_to_Computing_1st  Intro_to_Computing_2nd  \
# 0              0.0                    2.00                     0.0
# ...

# %%
X_IT
# Out:
#         Sex  Shiftee  ComProg_1_1st  ComProg_1_2nd  ComProg_2_1st  \
# 0      Male      1.0           2.00              0           2.75
# 1      Male      0.0           1.75              0           2.00
# 2    Female      1.0           1.50              0           1.50
# 3    Female      0.0           2.50              0           3.00
# 4      Male      1.0           1.75              0           1.25
# ..      ...      ...            ...            ...            ...
# 98   Female      0.0           2.00              0           2.25
# 99   Female      0.0           1.75              0           2.00
# 100    Male      1.0           1.75              0           1.75
# 101  Female      1.0           2.75              0           3.00
# 102  Female      0.0           1.50              0           1.50
#
#      ComProg_2_2nd  Intro_to_Computing_1st  Intro_to_Computing_2nd  \
# 0              0.0                    2.00                     0.0
# ...

# %%
backup = CS_REF.to_csv('CS_REFERENCE.csv', index = False, encoding='utf-8')
backup

# %%
plt.figure(figsize = (20,20))
sns.heatmap(X_IT.corr(), cmap="Reds", annot=True)
plt.show()

# %%
plt.figure(figsize=(20,30))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)
plt.subplot(141)
plt.title('Sex',fontsize = 20)
dataset['Sex'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(142)
plt.title('Shiftee',fontsize = 20)
dataset['SHIFTEE '].value_counts().plot.pie(autopct="%1.1f%%")

plt.show()
# BASED ON THE TOTAL RESPONDENTS 62.1% WERE MALE WHILE THE 37.9% WERE FEMALE

# %%
plt.figure(figsize=(20,30))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)

plt.subplot(141)
plt.title('Curriculum',fontsize = 20)
dataset['Curriculum'].value_counts().plot.pie(autopct="%1.1f%%")

plt.subplot(142)
plt.title('Units',fontsize = 20)
dataset['Units'].value_counts().plot.pie(autopct="%1.1f%%")

plt.show()

# %%
plt.figure(figsize=(20,30))
plt.subplots_adjust(left=0.125, bottom=0.1, right=0.9, top=0.9,
                      wspace=0.5, hspace=0.2)

plt.subplot(141)
plt.title('Degree Completed',fontsize = 20)
dataset['Degree_Completed'].value_counts().plot.pie(autopct="%1.1f%%")

plt.show()

# %%
sns.catplot('Suggested_job_role', data=dataset, kind='count', aspect=12/4)
# Out:
# C:\Users\France\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#As shown below we can conclude that the total units is the graduates academic performance and based on the four
#job roles we have, only the administrative assistant which is a Non-It related job has a less than five grouped units compare
#to the other IT related jobs which it has a lower number of units in total, While the rest IT-related job roles has
#a more than five grouped units and a higher number of total units.

pd.crosstab(dataset.Suggested_job_role,dataset.Units).plot(kind="bar",figsize=(20,6))
plt.title('Units Frequency for Job role')
plt.xlabel('Suggested job role')
plt.ylabel('Units')
plt.show()

# %%
#Given also the fact that the 2018-2019 curriculum 
pd.crosstab(dataset.Curriculum,dataset.Units).plot(kind="bar",figsize=(20,6))
plt.title('Units Frequency for Curriculum')
plt.xlabel('Curriculum')
plt.ylabel('Units')
plt.show()

# %%
pd.crosstab(dataset.Suggested_job_role,dataset.Degree_Completed).plot(kind="bar",figsize=(20,6))
plt.title('Degree Completed Frequency for Job role')
plt.xlabel('Suggested job role')
plt.ylabel('Degree Completed')
plt.show()

# %%
plt.scatter(dataset['Curriculum'], Y)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %%
dataset.plot(kind="scatter", x="Curriculum", y="Suggested_job_role")
plt.show()

# %%
plt.scatter(X, y)
plt.rcParams.update({'figure.figsize':(10,8), 'figure.dpi':100})
plt.title('Simple Scatter plot')
plt.xlabel('X - value')
plt.ylabel('Y - value')
plt.show()

# %% [markdown]
# # TOP 3 BACK-BREAKING COURSES IN BOTH IT AND CS

# %%
pd.crosstab(dataset.Suggested_job_role,dataset['Practicum_Industry_Immersion_1st']).plot(kind="bar",figsize=(20,6))
plt.title('Practicum/Industry Immersion Frequency for Job role')
plt.xlabel('Suggested job role')
plt.ylabel('Practicum/Industry Immersion')
plt.show()

# %%
pd.crosstab(dataset.Suggested_job_role,dataset['Data_Structures_1st']).plot(kind="bar",figsize=(20,6))
plt.title('Data Structures Frequency for Job role')
plt.xlabel('Suggested job role')
plt.ylabel('Data Structures 1')
plt.show()

# %%
pd.crosstab(dataset.Suggested_job_role,dataset['Operating_System_1st']).plot(kind="bar",figsize=(20,6))
plt.title('Operating System Frequency for Job role')
plt.xlabel('Suggested job role')
plt.ylabel('Operating System 1')
plt.show()

# %%
# plot histograms for each variable
dataset[['Sex',
 'Shiftee',
 'ComProg_1_1st',
 'ComProg_2_1st',
 'Intro_to_Computing_1st',
 'Info_Management_1st',
 'Operating_System_1st',
 'Elective_1_1st',
 'Elective_2_1st',
 'Elective_3_1st',
 'Data_Structures_1st',
 'Application_Dev_and_Emerging_Tech_1st',
 'Human_and_Computer_Integration_1st',
 'Practicum_Industry_Immersion_1st',
 'Digital_Design_1st',
 'Architecture_and_Organization_1st',
 'Programming_Languages_1st',
 'Modelling_and_Simulation_1st',
 'Information_Assurance_and_Security_1st',
 'Software_Engineering_1_1st',
 'Software_Engineering_2_1st',
 'Network_Management_1st',
 'Advance_Database_1st',
 'Integrative_Programming_and_Tech_1st',
 'System_Integration_and_Architecture_1st',
 'Information_Assurance_and_Security_1_1st',
 'Information_Assurance_and_Security_2_1st',
 'Software_Engineering_1st',
 'Networking_1_1st',
 'Networking_2_1st',
 'WebProg_1st'
  ]].hist(figsize = (30, 80))
plt.show()

# %%
#GENERATE A COPY OF CSV FILE
backup = dataset.to_csv('Institute of Computer Studies Graduate Tracer Study (2021-2022) (Responses)-TARGET_MERGED-5.0.csv', index = False, encoding='utf-8')
backup

# %% [markdown]
# ### BIVARIATE ANALYSIS USING SPEARMAN CORRELATION

# %%
import scipy
from scipy.stats import spearmanr

# %% [markdown]
# #### TESTING CORRELATION OF FIVE FEATURE ENGINEERED COLUMNS

# %%
testCorr1 = dataset[['SHIFTEE ', 'Suggested_job_role']].dropna()
testCorr1.head()
#SHIFTEE -6% CORRELATION = NO DIRECT CORRELATION TO THE TARGET
testCorr1.corr(method="spearman")
# Out:
#                     SHIFTEE   Suggested_job_role
# SHIFTEE             1.000000           -0.064962
# Suggested_job_role -0.064962            1.000000

# %%
testCorr2 = dataset[['Sex', 'Suggested_job_role']].dropna()
testCorr2.head()
#Sex 17.7% CORRELATION = HAS A WEAK CORRELATION TO THE TARGET
testCorr2.corr(method="spearman")
# Out:
#                          Sex  Suggested_job_role
# Sex                 1.000000            0.177521
# Suggested_job_role  0.177521            1.000000

# %%
testCorr3 = dataset[['Curriculum', 'Suggested_job_role']].dropna()
testCorr3.head()
#Curriculum 11.2% CORRELATION = HAS A WEAK CORRELATION TO THE TARGET
testCorr3.corr(method="spearman")
# Out:
#                     Curriculum  Suggested_job_role
# Curriculum            1.000000            0.112334
# Suggested_job_role    0.112334            1.000000

# %%
testCorr4 = dataset[['Degree_Completed', 'Suggested_job_role']].dropna()
testCorr4.head()
#Degree Completed 1.4% CORRELATION = HAS A NEGLIGIBLE CORRELATION TO THE TARGET
testCorr4.corr(method="spearman")
# Out:
#                     Degree_Completed  Suggested_job_role
# Degree_Completed            1.000000            0.014579
# Suggested_job_role          0.014579            1.000000

# %%
testCorr5 = dataset[['Units', 'Suggested_job_role']].dropna()
testCorr5.head()
#Units 11% CORRELATION = HAS A WEAK CORRELATION TO THE TARGET
testCorr5.corr(method="spearman")
# Out:
#                        Units  Suggested_job_role
# Units               1.000000            0.109657
# Suggested_job_role  0.109657            1.000000

# %%
rs = spearmanr(testCorr2)[0]

if abs(rs) < .10:
    qual = 'Negligible'
elif abs(rs) < .20:
    qual = 'Weak'
elif abs(rs) < .40:
    qual = 'Moderate'
elif abs(rs) < .60:
    qual = 'Relatively strong'
elif abs(rs) < .80:
    qual = 'Strong'
else:
    qual = 'Very strong'
    
qual
# Out:
# 'Weak'

# %% [markdown]
# # SCALING

# %%
from sklearn.preprocessing import Normalizer
from sklearn.preprocessing import StandardScaler, OrdinalEncoder, OneHotEncoder

# %%
ordinal_encoder = OrdinalEncoder()

# %%
X_IT['Sex'] = ordinal_encoder.fit_transform(X_IT[['Sex']])
X_CS['Sex'] = ordinal_encoder.fit_transform(X_CS[['Sex']])

# X['Curriculum'] = ordinal_encoder.fit_transform(X[['Curriculum']])
# X_pca['Curriculum'] = ordinal_encoder.fit_transform(X_pca[['Curriculum']])

# X['Degree_Completed'] = ordinal_encoder.fit_transform(X[['Degree_Completed']])
# X_pca['Degree_Completed'] = ordinal_encoder.fit_transform(X_pca[['Degree_Completed']])

# %%
normalized_data_IT = Normalizer().fit_transform(X_IT)
print(normalized_data_IT.shape)
# Out:
# (103, 42)

# %%
normalized_data_CS = Normalizer().fit_transform(X_CS)
print(normalized_data_CS.shape)
# Out:
# (103, 46)

# %%
normalized_data_IT
# Out:
# array([[0.12199886, 0.12199886, 0.24399771, ..., 0.        , 0.27449743,
#         0.        ],
#        [0.12137943, 0.        , 0.212414  , ..., 0.        , 0.24275885,
#         0.        ],
#        [0.        , 0.13223592, 0.19835388, ..., 0.        , 0.23141286,
#         0.        ],
#        ...,
#        [0.08703883, 0.08703883, 0.15231795, ..., 0.        , 0.23935678,
#         0.        ],
#        [0.        , 0.10663823, 0.29325514, ..., 0.        , 0.21327647,
#         0.        ],
#        [0.        , 0.        , 0.2038883 , ..., 0.        , 0.27185107,
#         0.        ]])

# %%
normalized_data_CS
# Out:
# array([[0.09076855, 0.09076855, 0.18153709, ..., 0.        , 0.20422923,
#         0.        ],
#        [0.12611333, 0.        , 0.22069833, ..., 0.        , 0.25222666,
#         0.        ],
#        [0.        , 0.1515108 , 0.22726621, ..., 0.        , 0.26514391,
#         0.        ],
#        ...,
#        [0.11206636, 0.11206636, 0.19611614, ..., 0.        , 0.3081825 ,
#         0.        ],
#        [0.        , 0.10663823, 0.29325514, ..., 0.        , 0.21327647,
#         0.        ],
#        [0.        , 0.        , 0.22759297, ..., 0.        , 0.3034573 ,
#         0.        ]])

# %% [markdown]
# # PCA

# %%
from sklearn.decomposition import PCA

# %%
def evaluate(components, eigenValues, eigenVectors, dataset):
    weightage = {}
    
    col = ['PC'+ str(i+1) for i in range(components.shape[1])]
    transform = pd.DataFrame(components, columns = col)
    display(transform)
    
    var = eigenValues/sum(eigenValues)
    for i in range(1,len(var)+1):
        if sum(var[:i])>=0.9:
            no_of_pc = i
            break
    print(f'\n{no_of_pc} components explains 90% or more variability')
    
    for i in range(no_of_pc):
        top_n = np.argsort( abs(eigenVectors[i]) )[::-1][:4] # shows top 4 affecting features
        weightage['PC'+str(i+1)] = [dataset.columns[j] for j in top_n]
    
    impact = pd.DataFrame.from_dict(weightage, orient='index')
    impact['Variability (%)'] = var[:no_of_pc]
    impact['Cummulative Variability (%)'] = [sum(var[:i]) for i in range(1,no_of_pc+1)]
    display(impact)
    return transform, impact, no_of_pc

# %%
def PCA_lib(dataset):
    pca = PCA(dataset.shape[1])
    pca.fit(dataset)
    eigenVectors = pca.components_.T
    eigenValues = pca.explained_variance_
    components = pca.transform(dataset)
    return components, eigenValues, eigenVectors

# %%
components, eigenValues, eigenVectors = PCA_lib(X_USE)

# %%
transform, impact, no_of_pc = evaluate(components, eigenValues, eigenVectors, X_USE)
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6       PC7  \
# 0   -2.870678 -3.826499 -2.270368  1.748880  0.525034 -1.423832 -2.192494
# 1   -2.914147  3.063734 -2.700909  0.900129  1.567401 -0.248717  0.532003
# 2   -2.228184  3.803099 -1.041918 -0.267413 -0.042593  0.489707  0.074144
# 3   -4.377057 -3.723624 -2.358390  1.924921 -1.982524 -2.684116  0.419062
# 4   -2.419677  4.080606 -0.404962 -0.114113  0.072456 -0.207912  0.975638
# ..        ...       ...       ...       ...       ...       ...       ...
# 98   3.476250  0.298048 -0.646757 -0.496506  0.258882  0.254037 -0.335565
# 99  -3.184023 -0.513102  3.657112 -1.338227 -1.159573  0.361660 -1.611948
# 100 -1.848307  4.839367  2.781845  0.990627 -0.238450 -0.553006 -0.060296
# 101  2.861115  0.412857 -0.373140 -0.227614  3.162315  1.729175 -1.283271
# 102 -2.218717  3.753497 -1.286175  0.103064 -0.363665  0.473285  0.144423
#
#           PC8       PC9      PC10  ...          PC60          PC61  \
# ...

# %%
no_of_pc
# Out:
# 18

# %% [markdown]
# # TRAIN-TEST SPLIT

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold

# %%
# X_pca = transform.iloc[:,list(range(0,no_of_pc))]

# %%
# Y = np.array(Y).reshape(-1,1)
# Y = ordinal_encoder.fit_transform(Y)
# Y = np.squeeze(Y)

# %%
#TRAIN-TEST SPLIT FOR IT
X_IT_train, X_IT_test, Y_IT_train, Y_IT_test = train_test_split(X_IT, Cat_Y, test_size=0.2, random_state=0)
print(X_IT_train.shape, X_IT_test.shape, Y_IT_train.shape, Y_IT_test.shape)
# Out:
# (82, 42) (21, 42) (82,) (21,)

# %%
#TRAIN-TEST SPLIT FOR CS
X_CS_train, X_CS_test, Y_CS_train, Y_CS_test = train_test_split(X_CS, Cat_Y, test_size=0.2, random_state=0)
print(X_CS_train.shape, X_CS_test.shape, Y_CS_train.shape, Y_CS_test.shape)
# Out:
# (82, 46) (21, 46) (82,) (21,)

# %% [markdown]
# # CLASSIFIERS

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
tuned_parameters_rfc = {'n_estimators' : [i for i in range(100,160,10)], 'criterion' : ['gini', 'entropy'], 
                        'max_depth' : list(range(15,40,5)), 'min_samples_split' : list(range(2,5)), 
                        'min_samples_leaf' : list(range(1,5)), 'max_leaf_nodes' : list(range(10,210,50)),'max_features' : ['auto', 'log2', None]}

# %%
#SET ESTIMATOR AND RANDOM STATE FOR IT
rfc_IT = RandomForestClassifier(random_state = 0, n_estimators = 150)
rfc_IT.fit(X_IT_train, Y_IT_train)
# Out:
# RandomForestClassifier(n_estimators=150, random_state=0)

# %%
#SET ESTIMATOR AND RANDOM STATE FOR CS
rfc_CS = RandomForestClassifier(random_state = 0, n_estimators = 150)
rfc_CS.fit(X_CS_train, Y_CS_train)
# Out:
# RandomForestClassifier(n_estimators=150, random_state=0)

# %%
pred_rfc_IT = rfc_IT.predict(X_IT_test)

# %%
pred_rfc_CS = rfc_CS.predict(X_CS_test)

# %% [markdown]
# #### K-fold Cross Validation

# %%
#K FOLD FOR IT
cv_IT = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
rfc_auc_IT = cross_val_score(rfc_IT, X_IT_train, Y_IT_train, scoring='roc_auc_ovo', cv=cv_IT, n_jobs=-1)
rfc_accuracy_IT = cross_val_score(rfc_IT, X_IT_train, Y_IT_train, scoring='accuracy', cv=cv_IT, n_jobs=-1)

# %%
pd.DataFrame([[accuracy_score(Y_IT_test, pred_rfc_IT), '-'],[np.mean(rfc_accuracy_IT), np.mean(rfc_auc_IT)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.095238         -
# K-fold      0.499265  0.780229

# %%
#K FOLD FOR CS
cv_CS = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
rfc_auc_CS = cross_val_score(rfc_CS, X_CS_train, Y_CS_train, scoring='roc_auc_ovo', cv=cv_CS, n_jobs=-1)
rfc_accuracy_CS = cross_val_score(rfc_CS, X_CS_train, Y_CS_train, scoring='accuracy', cv=cv_CS, n_jobs=-1)

# %%
pd.DataFrame([[accuracy_score(Y_CS_test, pred_rfc_CS), '-'],[np.mean(rfc_accuracy_CS), np.mean(rfc_auc_CS)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.142857         -
# K-fold      0.488971  0.725665

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
naive_IT = GaussianNB()
naive_IT.fit(X_IT_train, Y_IT_train)
# Out:
# GaussianNB()

# %%
naive_CS = GaussianNB()
naive_CS.fit(X_CS_train, Y_CS_train)
# Out:
# GaussianNB()

# %%
pred_naive_IT = naive_IT.predict(X_IT_test)

# %%
pred_naive_CS = naive_CS.predict(X_CS_test)

# %% [markdown]
# ### K-fold Cross Validation 10FOLDS

# %%
cvNaive_IT = KFold(n_splits=10, random_state=0, shuffle=True)
# evaluate model
naive_auc_IT = cross_val_score(naive_IT, X_IT_train, Y_IT_train, scoring='roc_auc_ovo', cv=cvNaive_IT, n_jobs=-1)
naive_accuracy_IT = cross_val_score(naive_IT, X_IT_train, Y_IT_train, scoring='accuracy', cv=cvNaive_IT, n_jobs=-1)

# %%
#WITH FIRST AND SECOND TRY GRADES
pd.DataFrame([[accuracy_score(Y_IT_test, pred_naive_IT), '-'],[np.mean(naive_accuracy_IT), np.mean(naive_auc_IT)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])

# %% [markdown]
# #### K-fold Cross Validation

# %%
cvNaive_IT = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
naive_auc_IT = cross_val_score(naive_IT, X_IT_train, Y_IT_train, scoring='roc_auc_ovo', cv=cvNaive_IT, n_jobs=-1)
naive_accuracy_IT = cross_val_score(naive_IT, X_IT_train, Y_IT_train, scoring='accuracy', cv=cvNaive_IT, n_jobs=-1)

# %%
#WITH FIRST AND SECOND TRY GRADES
pd.DataFrame([[accuracy_score(Y_IT_test, pred_naive_IT), '-'],[np.mean(naive_accuracy_IT), np.mean(naive_auc_IT)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.238095         -
# K-fold      0.391176  0.729108

# %%
cvNaive_CS = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
naive_auc_CS = cross_val_score(naive_CS, X_CS_train, Y_CS_train, scoring='roc_auc_ovo', cv=cvNaive_CS, n_jobs=-1)
naive_accuracy_CS = cross_val_score(naive_CS, X_CS_train, Y_CS_train, scoring='accuracy', cv=cvNaive_CS, n_jobs=-1)

# %%
#WITH FIRST AND SECOND TRY GRADES
pd.DataFrame([[accuracy_score(Y_CS_test, pred_naive_CS), '-'],[np.mean(naive_accuracy_CS), np.mean(naive_auc_CS)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.285714         -
# K-fold      0.392647  0.656747

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
tuned_parameters_log = {'penalty' : ['l2', 'none'], 'C' : [i for i in range(1,80,10)], 'class_weight' : [None,'balanced'], 
                        'max_iter' : [i for i in range(400,1000,100)]}

# %%
log_reg = LogisticRegression(solver = 'lbfgs', random_state = 0, C= 1, class_weight= None, max_iter = 400, penalty = 'l2')
log_reg.fit(X_train, Y_train)
# Out:
# LogisticRegression(C=1, max_iter=400, random_state=0)

# %%
pred_log = log_reg.predict(X_test)

# %% [markdown]
# #### K-fold Cross Validation

# %%
cv = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
log_auc = cross_val_score(log_reg, X_train, Y_train, scoring='roc_auc_ovo', cv=cv, n_jobs=-1)
log_accuracy = cross_val_score(log_reg, X_train, Y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
pd.DataFrame([[accuracy_score(Y_test, pred_log),  '-'],[np.mean(log_accuracy), np.mean(log_auc)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.047619         -
# K-fold      0.376471  0.618825

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
tuned_parameters_dtc = {'criterion' : ['gini', 'entropy'], 'max_depth' : list(range(3,7)), 'min_samples_split' : list(range(3,7)), 
                    'min_samples_leaf' : list(range(3,7)), 'max_leaf_nodes' : list(range(3,12))}

# %%
dtc = DecisionTreeClassifier(random_state = 0, criterion = 'gini', max_depth = 3, max_leaf_nodes = 4, min_samples_leaf = 3, min_samples_split = 3)
dtc.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, max_leaf_nodes=4, min_samples_leaf=3,
#                        min_samples_split=3, random_state=0)

# %%
pred_dtc = dtc.predict(X_test)

# %% [markdown]
# #### K-fold Cross Validation

# %%
cv = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
dtc_auc = cross_val_score(dtc, X_train, Y_train, scoring='roc_auc_ovo', cv=cv, n_jobs=-1)
dtc_accuracy = cross_val_score(dtc, X_train, Y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
pd.DataFrame([[accuracy_score(Y_test, pred_dtc), '-'],[np.mean(dtc_accuracy), np.mean(dtc_auc)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.190476         -
# K-fold      0.367647  0.594167

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC

# %%
tuned_parameters_svm = {'C': (np.arange(4,6,0.2)) , 'kernel': ['linear', 'rbf', 'poly'],
                    'gamma': [0.01,0.1,1,10], 'degree': [2,3,4]}

# %%
svm = SVC(probability=True, random_state = 0, C = 5, degree = 2, gamma = 0.01, kernel = 'linear')
svm.fit(X_train, Y_train)
# Out:
# SVC(C=5, degree=2, gamma=0.01, kernel='linear', probability=True,
#     random_state=0)

# %%
pred_svm = svm.predict(X_test)

# %% [markdown]
# #### K-fold Cross Validation

# %%
cv = KFold(n_splits=5, random_state=0, shuffle=True)
# evaluate model
svm_auc = cross_val_score(svm, X_train, Y_train, scoring='roc_auc_ovo', cv=cv, n_jobs=-1)
svm_accuracy = cross_val_score(svm, X_train, Y_train, scoring='accuracy', cv=cv, n_jobs=-1)

# %%
pd.DataFrame([[accuracy_score(Y_test, pred_svm), '-'],[np.mean(svm_accuracy),np.mean(svm_auc)]], columns = ['Accuracy', 'AUC'], index = ['Prediction', 'K-fold'])
# Out:
#             Accuracy       AUC
# Prediction  0.190476         -
# K-fold      0.341912  0.587783

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
tuned_parameters_knn = {'n_neighbors' : [i for i in range(3,13,2)]}

# %%
knn_model = KNeighborsClassifier()
knn = GridSearchCV(knn_model, tuned_parameters_knn, cv=5, scoring='accuracy')
knn.fit(X_train, Y_train)
knn.best_score_
# Out:
# 0.4522058823529411

# %%
knn.best_params_
# Out:
# {'n_neighbors': 7}

# %%
pred_knn = knn.predict(X_test)

# %% [markdown]
# # METRICS

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
model_pred_IT = {'Random Forest Classifier for IT' : pred_rfc_IT, 'Naive Bayes for IT' : pred_naive_IT}

# %%
model_pred_CS = {'Random Forest Classifier for CS' : pred_rfc_CS, 'Naive Bayes for CS' : pred_naive_CS}

# %% [markdown]
# #### Confusion Matrix

# %%
for v,k in model_pred_IT.items():
    print(f'{v} :\n{confusion_matrix(Y_IT_test, model_pred_IT[v])}\n\n\n')
# Out:
# Random Forest Classifier for IT :
# [[0 2 1 1]
#  [0 1 2 3]
#  [0 1 1 3]
#  [1 2 3 0]]
#
#
#
# Naive Bayes for IT :
# [[1 0 2 1]
#  [0 0 5 1]
#  [2 0 3 0]
#  [1 0 4 1]]

# %%
for v,k in model_pred_CS.items():
    print(f'{v} :\n{confusion_matrix(Y_CS_test, model_pred_CS[v])}\n\n\n')
# Out:
# Random Forest Classifier for CS :
# [[0 1 1 2]
#  [0 1 2 3]
#  [0 2 1 2]
#  [1 1 3 1]]
#
#
#
# Naive Bayes for CS :
# [[0 0 3 1]
#  [0 0 5 1]
#  [0 0 5 0]
#  [1 0 4 1]]

# %% [markdown]
# #### Classification Report

# %%
for v,k in model_pred_IT.items():
    print(f'{v} :\n{classification_report(Y_IT_test, model_pred_IT[v])}\n\n\n')
# Out:
# Random Forest Classifier for IT :
#                                 precision    recall  f1-score   support
#
#                    Academician       0.00      0.00      0.00         4
#       Administrative Assistant       0.17      0.17      0.17         6
# Software Engineer / Programmer       0.14      0.20      0.17         5
#   Technical Support Specialist       0.00      0.00      0.00         6
#
#                       accuracy                           0.10        21
#                      macro avg       0.08      0.09      0.08        21
#                   weighted avg       0.08      0.10      0.09        21
#
#
#
#
# Naive Bayes for IT :
#                                 precision    recall  f1-score   support
#
#                    Academician       0.25      0.25      0.25         4
#       Administrative Assistant       0.00      0.00      0.00         6
# Software Engineer / Programmer       0.21      0.60      0.32         5
# ...

# %%
for v,k in model_pred_CS.items():
    print(f'{v} :\n{classification_report(Y_CS_test, model_pred_CS[v])}\n\n\n')
# Out:
# Random Forest Classifier for CS :
#                                 precision    recall  f1-score   support
#
#                    Academician       0.00      0.00      0.00         4
#       Administrative Assistant       0.20      0.17      0.18         6
# Software Engineer / Programmer       0.14      0.20      0.17         5
#   Technical Support Specialist       0.12      0.17      0.14         6
#
#                       accuracy                           0.14        21
#                      macro avg       0.12      0.13      0.12        21
#                   weighted avg       0.13      0.14      0.13        21
#
#
#
#
# Naive Bayes for CS :
#                                 precision    recall  f1-score   support
#
#                    Academician       0.00      0.00      0.00         4
#       Administrative Assistant       0.00      0.00      0.00         6
# Software Engineer / Programmer       0.29      1.00      0.45         5
# ...

# %%
scores = {
    'Train' : {
#                'KNN': accuracy_score(Y_train, knn.predict(X_train)),
#                'Logistic':accuracy_score(Y_train, log_reg.predict(X_train)),
#                'SVM':accuracy_score(Y_train, svm.predict(X_train)),
#                'Decision Tree':accuracy_score(Y_train, dtc.predict(X_train)),
               'Naive Bayes for IT':accuracy_score(Y_IT_train, naive_IT.predict(X_IT_train)),
               'Naive Bayes for CS':accuracy_score(Y_IT_train, naive_CS.predict(X_CS_train)),
               'Random Forest for IT':accuracy_score(Y_IT_train, rfc_IT.predict(X_IT_train)),
               'Random Forest for CS':accuracy_score(Y_IT_train, rfc_CS.predict(X_CS_train))
              },
    'Test' : {
#                'KNN': accuracy_score(Y_test, pred_knn),
#                'Logistic':accuracy_score(Y_test, pred_log),
#                'SVM':accuracy_score(Y_test, pred_svm),
#                'Decision Tree':accuracy_score(Y_test, pred_dtc),
               'Naive Bayes for IT':accuracy_score(Y_IT_test, pred_naive_IT),
               'Naive Bayes for CS':accuracy_score(Y_CS_test, pred_naive_CS),
               'Random Forest for IT':accuracy_score(Y_IT_test, pred_rfc_IT),
               'Random Forest for CS':accuracy_score(Y_CS_test, pred_rfc_CS)
             }
}

# %%
scores_data = pd.DataFrame(scores)

scores_data.plot(kind='barh', figsize=(15,10))

plt.legend(loc = 'lower right')

# %% [markdown]
# # TRAINED MODEL

# %%
import pickle
from sklearn.metrics import confusion_matrix, classification_report

# %%
#RANDOM FOREST FOR IT
pickle.dump(rfc_IT, open('ProjectModel_IT.pkl', 'wb'))

# %%
#RANDOM FOREST FOR CS
pickle.dump(rfc_CS, open('ProjectModel_CS.pkl', 'wb'))

# %%
#NAIVE BAYES FOR IT
pickle.dump(naive_IT, open('ProjectModel_naiveIT.pkl', 'wb'))

# %%
#NAIVE BAYES FOR CS
pickle.dump(naive_CS, open('ProjectModel_naiveCS.pkl', 'wb'))

# %% [markdown]
# ### BATCH PREDICTION

# %%
test_model_IT = pickle.load(open('ProjectModel_IT.pkl', 'rb'))

# %%
test_model_CS = pickle.load(open('ProjectModel_CS.pkl', 'rb'))

# %%
test_model_naiveIT = pickle.load(open('ProjectModel_naiveIT.pkl', 'rb'))

# %%
test_model_naiveCS = pickle.load(open('ProjectModel_naiveCS.pkl', 'rb'))

# %%
# RANDOM FOREST RANGING FROM 40% TO 100% ACCURACY FOR IT
new_Xdata_IT = X_IT.sample(15)
new_Ydata_IT = Cat_Y[new_Xdata_IT.index.values]
pred_IT = test_model_IT.predict(new_Xdata_IT)

print(new_Xdata_IT,'\n\n', new_Ydata_IT)
print('\n\n', pred_IT)

res_cm_IT = confusion_matrix(new_Ydata_IT, pred_IT)
print('\n\nConfusion Matrix:\n\n', res_cm_IT)
res_acc_IT = accuracy_score(new_Ydata_IT, pred_IT)
print('\n\nAccuracy Score:', res_acc_IT)
# Out:
#     Sex  Shiftee  ComProg_1_1st  ComProg_1_2nd  ComProg_2_1st  ComProg_2_2nd  \
# 15  1.0      1.0           1.75              0           1.75            0.0
# 46  0.0      1.0           2.25              0           3.00            0.0
# 27  1.0      1.0           2.00              0           1.50            0.0
# 73  1.0      1.0           2.75              0           3.00            0.0
# 23  1.0      1.0           2.50              0           3.00            0.0
# 99  0.0      0.0           1.75              0           2.00            0.0
# 71  0.0      0.0           3.00              0           2.50            0.0
# 39  0.0      0.0           2.50              0           2.75            0.0
# 64  0.0      0.0           2.00              0           3.00            0.0
# 40  1.0      0.0           2.50              0           3.00            0.0
# 0   1.0      1.0           2.00              0           2.75            0.0
# ...

# %%
# RANDOM FOREST RANGING FROM 40% TO 100% ACCURACY FOR CS
new_Xdata_CS = X_CS.sample(15)
new_Ydata_CS = Cat_Y[new_Xdata_CS.index.values]
pred_CS = test_model_CS.predict(new_Xdata_CS)

print(new_Xdata_CS,'\n\n', new_Ydata_CS)
print('\n\n', pred_CS)

res_cm_CS = confusion_matrix(new_Ydata_CS, pred_CS)
print('\n\nConfusion Matrix:\n\n', res_cm_CS)
res_acc_CS = accuracy_score(new_Ydata_CS, pred_CS)
print('\n\nAccuracy Score:', res_acc_CS)
# Out:
#      Sex  Shiftee  ComProg_1_1st  ComProg_1_2nd  ComProg_2_1st  ComProg_2_2nd  \
# 15   1.0      1.0           1.75              0           1.75            0.0
# 38   1.0      0.0           3.00              0           3.00            0.0
# 6    1.0      0.0           1.25              0           1.75            0.0
# 24   1.0      0.0           1.50              0           1.50            0.0
# 43   1.0      0.0           2.75              0           2.75            0.0
# 77   1.0      0.0           2.00              0           1.75            0.0
# 71   0.0      0.0           3.00              0           2.50            0.0
# 39   0.0      0.0           2.50              0           2.75            0.0
# 86   0.0      0.0           2.00              0           2.00            0.0
# 36   0.0      1.0           3.00              0           5.00            2.5
# 32   1.0      0.0           2.75              0           3.00            0.0
# ...

# %%
# NAIVE BAYES RANGING FROM 20% TO 60% ACCURACY FOR IT
new_Xdata_naiveIT = X_IT.sample(15)
new_Ydata_naiveIT = Cat_Y[new_Xdata_naiveIT.index.values]
pred_naiveIT = test_model_naiveIT.predict(new_Xdata_naiveIT)

print(new_Xdata_naiveIT,'\n\n', new_Ydata_naiveIT)
print('\n\n', pred_naiveIT)

res_cm_naiveIT = confusion_matrix(new_Ydata_naiveIT, pred_naiveIT)
print('\n\nConfusion Matrix:\n\n', res_cm_naiveIT)
res_acc_naiveIT = accuracy_score(new_Ydata_naiveIT, pred_naiveIT)
print('\n\nAccuracy Score:', res_acc_naiveIT)
# Out:
#     Sex  Shiftee  ComProg_1_1st  ComProg_1_2nd  ComProg_2_1st  ComProg_2_2nd  \
# 82  0.0      0.0           1.25              0           2.25            0.0
# 43  1.0      0.0           2.75              0           2.75            0.0
# 83  1.0      0.0           2.50              0           2.00            0.0
# 53  1.0      0.0           3.00              0           2.75            0.0
# 93  0.0      0.0           3.00              0           1.75            0.0
# 46  0.0      1.0           2.25              0           3.00            0.0
# 64  0.0      0.0           2.00              0           3.00            0.0
# 63  1.0      0.0           2.75              0           2.75            0.0
# 35  1.0      0.0           2.50              0           2.25            0.0
# 9   1.0      0.0           2.75              0           2.00            0.0
# 65  1.0      0.0           5.00              3           5.00            3.0
# ...

# %%
# NAIVE BAYES RANGING FROM 26% TO 66% ACCURACY FOR CS
new_Xdata_naiveCS = X_CS.sample(15)
new_Ydata_naiveCS = Cat_Y[new_Xdata_naiveCS.index.values]
pred_naiveCS = test_model_naiveCS.predict(new_Xdata_naiveCS)

print(new_Xdata_naiveCS,'\n\n', new_Ydata_naiveCS)
print('\n\n', pred_naiveCS)

res_cm_naiveCS = confusion_matrix(new_Ydata_naiveCS, pred_naiveCS)
print('\n\nConfusion Matrix:\n\n', res_cm_naiveCS)
res_acc_naiveCS = accuracy_score(new_Ydata_naiveCS, pred_naiveCS)
print('\n\nAccuracy Score:', res_acc_naiveCS)
# Out:
#     Sex  Shiftee  ComProg_1_1st  ComProg_1_2nd  ComProg_2_1st  ComProg_2_2nd  \
# 92  0.0      0.0           2.75              0           3.00            0.0
# 62  1.0      0.0           2.25              0           2.50            0.0
# 48  1.0      1.0           1.25              0           1.75            0.0
# 46  0.0      1.0           2.25              0           3.00            0.0
# 42  0.0      1.0           3.00              0           2.75            0.0
# 39  0.0      0.0           2.50              0           2.75            0.0
# 59  0.0      0.0           2.50              0           1.75            0.0
# 91  1.0      0.0           2.00              0           2.00            0.0
# 1   1.0      0.0           1.75              0           2.00            0.0
# 57  1.0      0.0           3.00              0           2.25            0.0
# 55  1.0      0.0           3.00              0           5.00            2.0
# ...
